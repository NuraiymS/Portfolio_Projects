# %% [markdown]
# # Forbes billionaires 2022

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv(r'/Users/nuraiymsardarbekova/Downloads/2022_forbes_billionaires.csv')

df
# Out:
#       Unnamed: 0  rank                       name networth  age  \
# 0              0     1                 Elon Musk    $219 B   50
# 1              1     2                Jeff Bezos    $171 B   58
# 2              2     3  Bernard Arnault & family    $158 B   73
# 3              3     4                Bill Gates    $129 B   66
# 4              4     5            Warren Buffett    $118 B   91
# ...          ...   ...                        ...      ...  ...
# 2595        2595  2578    Jorge Gallardo Ballart      $1 B   80
# 2596        2596  2578              Nari Genomal      $1 B   82
# 2597        2597  2578            Ramesh Genomal      $1 B   71
# 2598        2598  2578            Sunder Genomal      $1 B   68
# 2599        2599  2578     Horst-Otto Gerberding      $1 B   69
#
#             country                  source                industry
# 0     United States           Tesla, SpaceX             Automotive
# ...

# %%
print(df.isnull().sum())
# Out:
# Unnamed: 0    0
# rank          0
# name          0
# networth      0
# age           0
# country       0
# source        0
# industry      0
# dtype: int64

# %%
df.dtypes
# Out:
# Unnamed: 0      int64
# rank            int64
# name           object
# networth      float64
# age             int64
# country        object
# source         object
# industry       object
# dtype: object

# %%
#remove the $ signs and convert the networth column to float:

df["networth"] = df["networth"].str.strip("$")
df["networth"] = df["networth"].str.strip("B")
df["networth"] = df["networth"].astype(float)

# %%
df.head()
# Out:
#    Unnamed: 0  rank                       name  networth  age        country  \
# 0           0     1                 Elon Musk      219.0   50  United States
# 1           1     2                Jeff Bezos      171.0   58  United States
# 2           2     3  Bernard Arnault & family      158.0   73         France
# 3           3     4                Bill Gates      129.0   66  United States
# 4           4     5            Warren Buffett      118.0   91  United States
#
#                source                industry
# 0       Tesla, SpaceX             Automotive
# 1              Amazon             Technology
# 2                LVMH       Fashion & Retail
# 3           Microsoft             Technology
# 4  Berkshire Hathaway  Finance & Investments

# %%
# Top 10

df1 = df.sort_values(by = ["networth"], ascending=False).head(10)
plt.figure(figsize=(10, 6))
plt.bar(df1["name"], df1["networth"])
plt.title("Net Worth by Name")
plt.xlabel("Name")
plt.ylabel("Net Worth")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
#top 5 sectors with the most number of billionaires

a = df["source"].value_counts().head()
index = a.index
sources = a.values
custom_colors = ["skyblue", "yellowgreen", 'tomato', "grey", "red"]
plt.figure(figsize=(5, 5))
plt.pie(sources, labels=index, colors=custom_colors, autopct='%1.0f%%')  # Added autopct parameter
central_circle = plt.Circle((0, 0), 0.5, color='white')
fig = plt.gcf()
fig.gca().add_artist(central_circle)
plt.rc('font', size=12)
plt.title("Top 5 Sectors to Become a Billionaire", fontsize=20)
plt.show()

# %%
b = df["industry"].value_counts().head()
index = b.index
industries = b.values
custom_colors = ["skyblue", "green", 'tomato', "pink", "red"]
plt.figure(figsize=(5, 5))
plt.pie(industries, labels=index, colors=custom_colors, autopct=lambda p: '{:.0f}'.format(p * sum(industries) / 100))
central_circle = plt.Circle((0, 0), 0.5, color='white')
fig = plt.gcf()
fig.gca().add_artist(central_circle)
plt.rc('font', size=12)
plt.title("Top 5 Industries with Most Number of Billionaires", fontsize=20)
plt.show()

# %%
c = df["country"].value_counts().head()
index = c.index
countries = c.values
custom_colors = ["skyblue", "yellowgreen", 'tomato', "pink", "red"]
plt.figure(figsize=(5, 5))
plt.pie(countries, labels=index, colors=custom_colors, autopct=lambda p: '{:.0f}'.format(p * sum(countries) / 100))
central_circle = plt.Circle((0, 0), 0.5, color='white')
fig = plt.gcf()
fig.gca().add_artist(central_circle)
plt.rc('font', size=12)
plt.title("Top 5 Countries with Most Number of Billionaires", fontsize=20)
plt.show()
